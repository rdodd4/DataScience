# %%
import pandas as pd
import numpy as np

# %%
M = pd.read_csv("MovieReviews.csv", index_col='Name')

# %%
M.columns
# Out:
# Index([u'American Sniper', u'The Hunger Games: Mockingjay - Part 1',
#        u'Guardians of the Galaxy', u'The Lego Movie', u'The Hobbit',
#        u'Transformers', u'Malificent', u'Big Hero 6', u'Godzilla',
#        u'Interstellar', u'How to Train your Dragon 2', u'Gone Girl',
#        u'Divergent', u'The Fault in Our Stars', u'Unbroken',
#        u'300: Rise of an Empire', u'Unnamed: 17', u'Unnamed: 18',
#        u'Unnamed: 19', u'Unnamed: 20', u'Unnamed: 21', u'Unnamed: 22',
#        u'Unnamed: 23', u'Unnamed: 24', u'Unnamed: 25'],
#       dtype='object')

# %%
del M['Unnamed: 17']
del M['Unnamed: 18']
del M['Unnamed: 19']
del M['Unnamed: 20']
del M['Unnamed: 21']
del M['Unnamed: 22']
del M['Unnamed: 23']
del M['Unnamed: 24']
del M['Unnamed: 25']

# %%
M
# Out:
#                     American Sniper  The Hunger Games: Mockingjay - Part 1  \
# Name
# Aarti Jaiswal                   4.0                                    NaN
# Aditya Dharmasagar              5.0                                    NaN
# Adrian Cavallaris               NaN                                    4.0
# Ahmed Muheebuddin               5.0                                    NaN
# Aishwarya reddy                 NaN                                    3.0
# Akhilesh                        NaN                                    NaN
# Andrew Webb                     4.0                                    3.0
# Anirudh                         3.0                                    4.0
# Anirudh Thota                   NaN                                    3.0
# anurag                          4.0                                    NaN
# Anusha Putta                    NaN                                    NaN
# ...

# %% [markdown]
# ### Question 1: What movie is most Similar to 'The fault in our stars'

# %%
def pearson(s1, s2):
    """Take two pd.Series objects and return a pearson correlation."""
    s1_c = s1 - s1.mean()
    s2_c = s2 - s2.mean()
    return np.sum(s1_c * s2_c) / np.sqrt(np.sum(s1_c ** 2) * np.sum(s2_c ** 2))

# %%
def get_recs(movie_name, M, num):

    import numpy as np
    
    reviews = []
    for title in M.columns:
        if title == movie_name:
            continue
        cor = pearson(M[movie_name], M[title])
        if np.isnan(cor):
            continue
        else:
            reviews.append((title, cor))
    
    reviews.sort(key=lambda tup: tup[1], reverse=True)
    return reviews[:num]

# %%
similar_movies = get_recs('The Fault in Our Stars', M, 1)

# %%
similar_movies
# Out:
# [('Interstellar', 0.2178645563053444)]

# %% [markdown]
# ### It looks like Interstellar is rated similar as The Fault in Our Stars

# %% [markdown]
# ### Question 2: Which movie(s) would you most like to see, based on your classmates experience? (40 pts)

# %%
my_ratings = M.ix['Ramya Doddi'].dropna()
my_ratings.sort(ascending=False)
fav_movie = my_ratings.index[0]
# Out:
# C:\Users\Ramya\Anaconda2\lib\site-packages\ipykernel\__main__.py:2: FutureWarning: sort is deprecated, use sort_values(inplace=True) for INPLACE sorting
#   from ipykernel import kernelapp as app

# %%
fav_movie
# Out:
# 'How to Train your Dragon 2'

# %%
recommended_movies= get_recs(fav_movie, M, 10)
recommended_movies
# Out:
# [('The Lego Movie', 0.25693462091371344),
#  ('Gone Girl', 0.25359363127771883),
#  ('Godzilla', 0.23015699726560557),
#  ('Divergent', 0.18372324226205478),
#  ('Transformers', 0.16746606090615826),
#  ('Guardians of the Galaxy', 0.14309274752364917),
#  ('American Sniper', 0.13240890548809034),
#  ('Interstellar', 0.12438784211431489),
#  ('Big Hero 6', 0.11424420459501625),
#  ('The Fault in Our Stars', 0.094321109306395534)]

# %% [markdown]
# ### Question 3: Bonus Question... For all the movies you haven't seen, can you predict how you'd rate them using your the class reviews?

# %%
#Complete list of the movies that I have rated and not rated
mylist = M.ix['Ramya Doddi']
mylist.sort(ascending=False)
ratings = mylist.index[0]
# Out:
# C:\Users\Ramya\Anaconda2\lib\site-packages\ipykernel\__main__.py:3: FutureWarning: sort is deprecated, use sort_values(inplace=True) for INPLACE sorting
#   app.launch_new_instance()

# %%
#Movies that I have not rated 
mylist[mylist.isnull()]
# Out:
# American Sniper           NaN
# Guardians of the Galaxy   NaN
# The Lego Movie            NaN
# Gone Girl                 NaN
# The Fault in Our Stars    NaN
# Unbroken                  NaN
# Name: Ramya Doddi, dtype: float64

# %%
#Similar to my not rated movie list

# %%
similar_movie1= get_recs('American Sniper', M, 1)

# %%
similar_movie1
# Out:
# [('The Lego Movie', 0.20575970080333875)]

# %%
similar_movie2= get_recs('Guardians of the Galaxy', M, 1)
similar_movie2
# Out:
# [('The Lego Movie', 0.42863738310413624)]

# %%
similar_movie3= get_recs('The Lego Movie', M, 1)
similar_movie3
# Out:
# [('Guardians of the Galaxy', 0.42863738310413624)]

# %%
similar_movie4= get_recs('Gone Girl', M, 1)
similar_movie4
# Out:
# [('How to Train your Dragon 2', 0.25359363127771883)]

# %%
similar_movie5= get_recs('The Fault in Our Stars', M, 1)
similar_movie5
# Out:
# [('Interstellar', 0.2178645563053444)]

# %%
similar_movie6= get_recs('Unbroken', M, 1)
similar_movie6
# Out:
# [('The Fault in Our Stars', 0.17273639371993235)]

# %%
#function to give most likely rating based on the predicted movie by taking mean  
def get_ratings(movie):
    recommended_movie=get_recs(movie,M,1)
    movie_name=[i[0] for i in recommended_movie]
    movie_rating = M[movie_name].mean()
    rating=(movie,round(movie_rating))
    return rating

# %%
not_rated=['American Sniper','Guardians of the Galaxy','The Lego Movie','Gone Girl','The Fault in Our Stars','Unbroken']

for u in not_rated:
    rated=get_ratings(u)
    print rated
# Out:
# ('American Sniper', 3.0)
# ('Guardians of the Galaxy', 3.0)
# ('The Lego Movie', 4.0)
# ('Gone Girl', 4.0)
# ('The Fault in Our Stars', 5.0)
# ('Unbroken', 4.0)

# %%
#The above are the movie ratings based on my classmates reviews of them!
